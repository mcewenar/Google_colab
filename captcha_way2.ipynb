# %% [markdown]
# <a href="https://colab.research.google.com/github/mcewenar/Google_colab/blob/master/captcha_way2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install captcha

from captcha.image import ImageCaptcha
import random

#Specify the image size
image = ImageCaptcha(width=450, height=100)

#Generate random captcha text
def generate_random_captcha_text(length=6):
  characters ='abcdefghijklmnñopqrstuvwxyzABCDEFGHIJKLMNÑOPQRSTUVWXYZ1234567890'
  captcha_text = ''.join(random.choice(characters) for _ in range(length))
  return captcha_text


#Get random captcha text
captcha_text = generate_random_captcha_text()

#Generate the image of the given text
text_capt = "hola"
#data = image.generate(captcha_text)

#Write the image on the given file and save it
image.write(captcha_text, 'captcha1.png')

from PIL import Image
Image.open('captcha1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x100>

# %%
# Import the following modules
from captcha.image import ImageCaptcha

# Create an image instance of the given size
image = ImageCaptcha(width = 280, height = 90)

# Image captcha text
captcha_text = 'GeeksforGeeks'

# generate the image of the given text
data = image.generate(captcha_text)

# write the image on the given file and save it
image.write(captcha_text, 'CAPTCHA.png')
