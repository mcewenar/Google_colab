# %% [markdown]
# <a href="https://colab.research.google.com/github/mcewenar/Google_colab/blob/master/bruteForcePsswrd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import *

user_pass = input("Enter password: ")

#storing alphabet letter to use them to crack password
password = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n','ñ','o','p','q','r','s','t','u','v','w','x','y','z']

#Initializing an empty string
guess = ""

#Using while loop to generate many password by brute force till one of them does matches user_pass
while (guess != user_pass):
  guess = ""
  #generating random password using for loop:
  for letter in range(len(user_pass)):
    guess_letter = password[randint(0,26)]
    guess = str(guess_letter) + str(guess)
  #printing guessed password;
  print(guess)

#Printing the matched password
print("Your password is", guess)
# Out:
# Streaming output truncated to the last 5000 lines.
# yqaz
# zwbc
# cmxj
# jwgt
# yyqa
# bfpx
# aqff
# bjnb
# slez
# mpix
# ifdl
# mmpp
# ueem
# izye
# idbi
# jldz
# bkgc
# ikmo
# gqzr
# bzcg
# jkgv
# sers
# feab
# siie
# yxzl
# qdjh
# gyhf
# rsxi
# xoru
# rjjp
# soxv
# vbcl
# nkdy
# fhat
# aokv
# kfhu
# xwex
# zrgh
# kszr
# pdkr
# vzvd
# hroi
# hlne
# kyxi
# uzll
# yxca
# wyad
# yams
# syfd
# rell
# lgvy
# dfdc
# vvxx
# ckmr
# ervt
# vmds
# uueñ
# vqiu
# qmoh
# xqfñ
# feun
# reao
# apin
# cjtn
# rerv
# wnoj
# anyn
# mdkh
# hgbi
# jnjf
# wwln
# owcm
# mmuc
# zamñ
# iññi
# jftv
# nxñf
# zwht
# qvyp
# ltat
# fwsv
# jlut
# nuzk
# wywn
# toqb
# irlp
# ymji
# esif
# etdb
# rupm
# zmxx
# selt
# xupi
# zoon
# hqvk
# ñjcx
# jyyp
# mmmk
# sbct
# vcmr
# uupm
# snhg
# omjn
# wpoi
# wqdz
# rlab
# babz
# zaej
# aoñe
# eoav
# kxha
# llsu
# lbñk
# qnzd
# asdo
# qazz
# oquñ
# izrw
# prdu
# bpkx
# mwñg
# dñtc
# iñxh
# xoao
# hawm
# wwñi
# ukqm
# oecu
# poht
# sgod
# exil
# jgvh
# txeq
# cplz
# degv
# ...
